# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from citipy) (0.16)

# %%
import pandas as pd
import json
import requests
import random as rand
import matplotlib.pyplot as plt
from api_keys import weather_api_key
from citipy import citipy
from scipy.stats import linregress

base_url = "http://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Generate Cities List

# %%
city_list = []

# create random geo-coordinates and use citipy to gather city names onto a list
for i in range(0, 550):
    city = citipy.nearest_city(rand.uniform(-90, 90), rand.uniform(-180, 180))
    
    # create while loop that re-rolls geo-coordinates for a city that isn't already in list
    while city.city_name in city_list:
        city = citipy.nearest_city(rand.uniform(-90, 90), rand.uniform(-180, 180))
    city_list.append(city.city_name)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_data = {
    'City': [],
    'Lat': [],
    'Lng': [],
    'Max Temp': [],
    'Humidity': [],
    'Cloudiness': [],
    'Wind Speed': [],
    'Country': [],
    'Date': []
}

print('Beginning Data Retrieval')
print('-----------------------------')


# iterate through city list and get API response and try to add information from each city into df dictionary
for i in range(len(city_list)):
    set_no = ((i + 1) // 50) + 1
    query_url = f"{base_url}q={city_list[i]}&appid={weather_api_key}&units=imperial"

    try:
        response = requests.get(query_url).json()
        city_data['City'].append(response['name'])
        city_data['Lat'].append(response['coord']['lat'])
        city_data['Lng'].append(response['coord']['lon'])
        city_data['Max Temp'].append(response['main']['temp_max'])
        city_data['Humidity'].append(response['main']['humidity'])
        city_data['Cloudiness'].append(response['clouds']['all'])
        city_data['Wind Speed'].append(response['wind']['speed'])
        city_data['Country'].append(response['sys']['country'])
        city_data['Date'].append(response['dt'])
        print(f"Processing Record {(i + 1) % 50} of Set {set_no} | {city_list[i]}")
    except KeyError:
        print('City not found. Skipping...')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gamba
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | samarai
# Processing Record 4 of Set 1 | fayaoue
# Processing Record 5 of Set 1 | ilulissat
# Processing Record 6 of Set 1 | sitka
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | lakkion
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | lavrentiya
# Processing Record 13 of Set 1 | el ocotito
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | inirida
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | broken hill
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | boddam
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | chokurdakh
# City not found. Skipping...
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | spearfish
# Processing Record 28 of Set 1 | quang ngai
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | berlevag
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | dingle
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | mogadouro
# Processing Record 38 of Set 1 | alice springs
# Processing Record 39 of Set 1 | esperance
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | san patricio
# Processing Record 44 of Set 1 | hangu
# Processing Record 45 of Set 1 | bhilwara
# Processing Record 46 of Set 1 | port hardy
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | manuk mangkaw
# Processing Record 0 of Set 2 | wanning
# Processing Record 1 of Set 2 | pandharpur
# Processing Record 2 of Set 2 | rio gallegos
# Processing Record 3 of Set 2 | bagdarin
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | sorland
# Processing Record 6 of Set 2 | isangel
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | klaksvik
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | santa fe
# City not found. Skipping...
# Processing Record 14 of Set 2 | dubbo
# Processing Record 15 of Set 2 | porbandar
# Processing Record 16 of Set 2 | mandera
# Processing Record 17 of Set 2 | santarem
# Processing Record 18 of Set 2 | manggar
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | acapulco
# Processing Record 21 of Set 2 | bilma
# Processing Record 22 of Set 2 | paamiut
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | evensk
# Processing Record 26 of Set 2 | sao filipe
# Processing Record 27 of Set 2 | dareda
# Processing Record 28 of Set 2 | mbandaka
# Processing Record 29 of Set 2 | bozoum
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | tiarei
# Processing Record 33 of Set 2 | mogadishu
# Processing Record 34 of Set 2 | saint-augustin
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | voh
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | otofuke
# Processing Record 39 of Set 2 | olenegorsk
# Processing Record 40 of Set 2 | hami
# Processing Record 41 of Set 2 | laguna
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | yibin
# Processing Record 44 of Set 2 | zhaodong
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | dongsheng
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | irbil
# Processing Record 49 of Set 2 | saint-leu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# City not found. Skipping...
# Processing Record 34 of Set 4 | mwinilunga
# Processing Record 35 of Set 4 | kaabong
# City not found. Skipping...
# Processing Record 37 of Set 4 | goderich
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | komsomolskiy
# Processing Record 40 of Set 4 | monte santo
# Processing Record 41 of Set 4 | alenquer
# Processing Record 42 of Set 4 | moyale
# Processing Record 43 of Set 4 | mitsamiouli
# Processing Record 44 of Set 4 | bilibino
# Processing Record 45 of Set 4 | savannah bight
# Processing Record 46 of Set 4 | wanaka
# Processing Record 47 of Set 4 | southbridge
# Processing Record 48 of Set 4 | miles city
# Processing Record 49 of Set 4 | bodden town
# Processing Record 0 of Set 5 | voi
# Processing Record 1 of Set 5 | severo-kurilsk
# Processing Record 2 of Set 5 | clinton
# Processing Record 3 of Set 5 | mayo
# Processing Record 4 of Set 5 | el alto
# City not found. Skipping...
# Processing Record 6 of Set 5 | touros
# Processing Record 7 of Set 5 | ati
# Processing Record 8 of Set 5 | ndende
# Processing Record 9 of Set 5 | sept-iles
# Processing Record 10 of Set 5 | college
# Processing Record 11 of Set 5 | maryville
# Processing Record 12 of Set 5 | beltinci
# Processing Record 13 of Set 5 | menzelinsk
# Processing Record 14 of Set 5 | kahului
# Processing Record 15 of Set 5 | vardo
# City not found. Skipping...
# Processing Record 17 of Set 5 | saiha
# City not found. Skipping...
# Processing Record 19 of Set 5 | sola
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | ahipara
# Processing Record 22 of Set 5 | lagoa
# Processing Record 23 of Set 5 | faya
# Processing Record 24 of Set 5 | puquio
# Processing Record 25 of Set 5 | tura
# Processing Record 26 of Set 5 | chiang klang
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | syamzha
# Processing Record 29 of Set 5 | port moresby
# Processing Record 30 of Set 5 | asau
# Processing Record 31 of Set 5 | beaufort
# City not found. Skipping...
# Processing Record 33 of Set 5 | shuya
# Processing Record 34 of Set 5 | ust-nera
# Processing Record 35 of Set 5 | zakamensk
# City not found. Skipping...
# Processing Record 37 of Set 5 | kapit
# Processing Record 38 of Set 5 | primorsk
# Processing Record 39 of Set 5 | east london
# Processing Record 40 of Set 5 | coquimbo
# Processing Record 41 of Set 5 | rabaul
# Processing Record 42 of Set 5 | pevek
# Processing Record 43 of Set 5 | hamilton
# Processing Record 44 of Set 5 | almaznyy
# Processing Record 45 of Set 5 | batagay-alyta
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | kiama
# Processing Record 48 of Set 5 | vigrestad
# Processing Record 49 of Set 5 | taszar
# Processing Record 0 of Set 6 | smoky lake
# Processing Record 1 of Set 6 | tessalit
# City not found. Skipping...
# Processing Record 3 of Set 6 | sao felix do xingu
# Processing Record 4 of Set 6 | grand gaube
# Processing Record 5 of Set 6 | batagay
# Processing Record 6 of Set 6 | gouyave
# Processing Record 7 of Set 6 | conceicao da barra
# Processing Record 8 of Set 6 | buraydah
# Processing Record 9 of Set 6 | esso
# Processing Record 10 of Set 6 | khash
# Processing Record 11 of Set 6 | naron
# Processing Record 12 of Set 6 | severodvinsk
# City not found. Skipping...
# Processing Record 14 of Set 6 | burgersdorp
# Processing Record 15 of Set 6 | ambulu
# Processing Record 16 of Set 6 | ada
# Processing Record 17 of Set 6 | yar-sale
# Processing Record 18 of Set 6 | prince rupert
# Processing Record 19 of Set 6 | dauphin
# Processing Record 20 of Set 6 | goroka
# Processing Record 21 of Set 6 | bama
# Processing Record 22 of Set 6 | taltal
# City not found. Skipping...
# Processing Record 24 of Set 6 | ketchikan
# City not found. Skipping...
# Processing Record 26 of Set 6 | kuusamo
# Processing Record 27 of Set 6 | dunda
# Processing Record 28 of Set 6 | port macquarie
# Processing Record 29 of Set 6 | hayden
# Processing Record 30 of Set 6 | magaria
# Processing Record 31 of Set 6 | oussouye
# Processing Record 32 of Set 6 | maragogi
# City not found. Skipping...
# Processing Record 34 of Set 6 | hithadhoo
# Processing Record 35 of Set 6 | iraucuba
# City not found. Skipping...
# Processing Record 37 of Set 6 | atar
# Processing Record 38 of Set 6 | leningradskiy
# Processing Record 39 of Set 6 | longyearbyen
# Processing Record 40 of Set 6 | luderitz
# City not found. Skipping...
# Processing Record 42 of Set 6 | eston
# Processing Record 43 of Set 6 | tasiilaq
# Processing Record 44 of Set 6 | petlawad
# Processing Record 45 of Set 6 | tra vinh
# Processing Record 46 of Set 6 | dunedin
# Processing Record 47 of Set 6 | kirillov
# Processing Record 48 of Set 6 | saint-pierre
# City not found. Skipping...
# Processing Record 0 of Set 7 | srednekolymsk
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | luena
# Processing Record 3 of Set 7 | lorengau
# Processing Record 4 of Set 7 | narsaq
# Processing Record 5 of Set 7 | gobabis
# Processing Record 6 of Set 7 | lyubim
# Processing Record 7 of Set 7 | yamada
# Processing Record 8 of Set 7 | nusaybin
# Processing Record 9 of Set 7 | maniitsoq
# Processing Record 10 of Set 7 | axim
# Processing Record 11 of Set 7 | benguela
# Processing Record 12 of Set 7 | sambava
# Processing Record 13 of Set 7 | harper
# Processing Record 14 of Set 7 | zalantun
# City not found. Skipping...
# Processing Record 16 of Set 7 | vozhega
# Processing Record 17 of Set 7 | monrovia
# Processing Record 18 of Set 7 | labuhan
# Processing Record 19 of Set 7 | boyolangu
# Processing Record 20 of Set 7 | clyde river
# Processing Record 21 of Set 7 | agropoli
# Processing Record 22 of Set 7 | shitanjing
# Processing Record 23 of Set 7 | san prisco
# Processing Record 24 of Set 7 | bonavista
# Processing Record 25 of Set 7 | ouadda
# Processing Record 26 of Set 7 | aksarka
# Processing Record 27 of Set 7 | hachinohe
# Processing Record 28 of Set 7 | manoel urbano
# Processing Record 29 of Set 7 | geraldton
# Processing Record 30 of Set 7 | olafsvik
# Processing Record 31 of Set 7 | tromso
# Processing Record 32 of Set 7 | makat
# Processing Record 10 of Set 9 | kruisfontein
# Processing Record 11 of Set 9 | zhoucheng
# Processing Record 12 of Set 9 | boende
# Processing Record 13 of Set 9 | kudahuvadhoo
# City not found. Skipping...
# Processing Record 15 of Set 9 | uray
# Processing Record 16 of Set 9 | nantucket
# Processing Record 17 of Set 9 | eyl
# Processing Record 18 of Set 9 | nabire
# Processing Record 19 of Set 9 | guerrero negro
# Processing Record 20 of Set 9 | yulara
# Processing Record 21 of Set 9 | kenai
# Processing Record 22 of Set 9 | kyren
# Processing Record 23 of Set 9 | ferrol
# Processing Record 24 of Set 9 | port shepstone
# Processing Record 25 of Set 9 | kedrovyy
# Processing Record 26 of Set 9 | deputatskiy
# Processing Record 27 of Set 9 | tampere
# Processing Record 28 of Set 9 | san andres
# Processing Record 29 of Set 9 | westport
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 9 | ishigaki
# Processing Record 33 of Set 9 | dumas
# Processing Record 34 of Set 9 | shache
# Processing Record 35 of Set 9 | edgewater
# Processing Record 36 of Set 9 | salair
# Processing Record 37 of Set 9 | terney
# Processing Record 38 of Set 9 | kaitangata
# Processing Record 39 of Set 9 | udachnyy
# Processing Record 40 of Set 9 | coracora
# Processing Record 41 of Set 9 | tyret pervaya
# Processing Record 42 of Set 9 | shar
# Processing Record 43 of Set 9 | tual
# Processing Record 44 of Set 9 | richards bay
# Processing Record 45 of Set 9 | haines junction
# Processing Record 46 of Set 9 | develi
# Processing Record 47 of Set 9 | edd
# Processing Record 48 of Set 9 | immokalee
# City not found. Skipping...
# Processing Record 0 of Set 10 | inongo
# Processing Record 1 of Set 10 | yairipok
# Processing Record 2 of Set 10 | syracuse
# Processing Record 3 of Set 10 | sri aman
# Processing Record 4 of Set 10 | arona
# Processing Record 5 of Set 10 | saint anthony
# Processing Record 6 of Set 10 | asfi
# Processing Record 7 of Set 10 | nanakuli
# Processing Record 8 of Set 10 | salisbury
# Processing Record 9 of Set 10 | kachiry
# Processing Record 10 of Set 10 | leopoldsburg
# City not found. Skipping...
# Processing Record 12 of Set 10 | seoul
# City not found. Skipping...
# Processing Record 14 of Set 10 | pandan
# Processing Record 15 of Set 10 | nakamura
# City not found. Skipping...
# Processing Record 17 of Set 10 | port-cartier
# Processing Record 18 of Set 10 | meulaboh
# Processing Record 19 of Set 10 | crailsheim
# Processing Record 20 of Set 10 | poli
# Processing Record 21 of Set 10 | tiznit
# Processing Record 22 of Set 10 | hargeysa
# Processing Record 23 of Set 10 | sao joao da barra
# Processing Record 24 of Set 10 | port augusta
# Processing Record 25 of Set 10 | tuy hoa
# Processing Record 26 of Set 10 | sarh
# Processing Record 27 of Set 10 | mabai
# City not found. Skipping...
# Processing Record 29 of Set 10 | cockburn town
# Processing Record 30 of Set 10 | qaqortoq
# Processing Record 31 of Set 10 | qena
# Processing Record 32 of Set 10 | kununurra
# Processing Record 33 of Set 10 | ucluelet
# Processing Record 34 of Set 10 | bamiantong
# Processing Record 35 of Set 10 | cap malheureux
# Processing Record 36 of Set 10 | lakes entrance
# Processing Record 37 of Set 10 | lata
# Processing Record 38 of Set 10 | mount isa
# Processing Record 39 of Set 10 | non sang
# Processing Record 40 of Set 10 | emba
# Processing Record 41 of Set 10 | kichera
# Processing Record 42 of Set 10 | vero beach
# Processing Record 43 of Set 10 | rumonge
# City not found. Skipping...
# Processing Record 45 of Set 10 | kamennomostskoye
# Processing Record 46 of Set 10 | xining
# Processing Record 47 of Set 10 | kosa
# Processing Record 48 of Set 10 | kanniyakumari
# Processing Record 49 of Set 10 | manakara
# Processing Record 0 of Set 11 | puerto del rosario
# Processing Record 1 of Set 11 | prince george
# Processing Record 2 of Set 11 | susehri
# Processing Record 3 of Set 11 | atagay
# Processing Record 4 of Set 11 | lazaro cardenas
# City not found. Skipping...
# Processing Record 6 of Set 11 | gualaquiza
# Processing Record 7 of Set 11 | shaunavon
# Processing Record 8 of Set 11 | gondar
# Processing Record 9 of Set 11 | khani
# Processing Record 10 of Set 11 | acatlan
# Processing Record 11 of Set 11 | venustiano carranza
# Processing Record 12 of Set 11 | tuatapere
# Processing Record 13 of Set 11 | zeewolde
# Processing Record 14 of Set 11 | san rafael
# Processing Record 15 of Set 11 | panama city
# Processing Record 16 of Set 11 | coro
# Processing Record 17 of Set 11 | kizema
# Processing Record 18 of Set 11 | lima
# Processing Record 19 of Set 11 | sakakah
# Processing Record 20 of Set 11 | itarema
# Processing Record 21 of Set 11 | limbang
# Processing Record 22 of Set 11 | bireun
# Processing Record 23 of Set 11 | tadine
# Processing Record 24 of Set 11 | buala
# Processing Record 25 of Set 11 | aloleng
# Processing Record 26 of Set 11 | arlit
# Processing Record 27 of Set 11 | saint-joseph
# Processing Record 28 of Set 11 | chadan
# Processing Record 29 of Set 11 | nautanwa
# Processing Record 30 of Set 11 | altamirano
# Processing Record 31 of Set 11 | thyboron
# Processing Record 32 of Set 11 | pudozh
# City not found. Skipping...
# Processing Record 34 of Set 11 | khudumelapye
# Processing Record 35 of Set 11 | pueblo bello
# Processing Record 36 of Set 11 | nuuk
# Processing Record 37 of Set 11 | vaitape
# Processing Record 38 of Set 11 | ugoofaaru
# Processing Record 39 of Set 11 | savinka
# City not found. Skipping...
# Processing Record 41 of Set 11 | isla vista
# Processing Record 42 of Set 11 | road town
# Processing Record 43 of Set 11 | chifeng
# Processing Record 44 of Set 11 | ginir
# Processing Record 45 of Set 11 | yoichi
# Processing Record 46 of Set 11 | iquique
# Processing Record 47 of Set 11 | sri madhopur
# Processing Record 48 of Set 11 | saint-francois
# Processing Record 49 of Set 11 | san policarpo
# Processing Record 0 of Set 12 | puerto baquerizo moreno

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create dataframe and export to csv
city_df = pd.DataFrame(city_data)
city_df.to_csv('output_data/cities.csv')

city_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Gamba  -2.65   10.00     77.43        87          84        8.12
# 1  Nikolskoye  59.70   30.79     37.99        93          75        6.71
# 2     Samarai -10.62  150.67     80.62        86          94       12.08
# 3     Fayaoué -20.65  166.53     75.13        74          19        9.40
# 4   Ilulissat  69.22  -51.10     42.80        70         100       10.29
#
#   Country        Date
# 0      GA  1603090226
# 1      RU  1603090227
# 2      PG  1603090227
# 3      NC  1603090227
# 4      GL  1603090228

# %%
city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  502.000000  502.000000  502.000000  502.000000  502.000000  502.000000
# mean    20.647888   20.465458   61.235080   71.948207   55.472112    7.923446
# std     32.971161   90.070919   20.643269   21.992770   40.156409    5.599348
# min    -54.800000 -175.200000   -2.200000   10.000000    0.000000    0.160000
# 25%     -4.795000  -61.340000   44.192500   62.250000   11.000000    3.360000
# 50%     22.385000   26.625000   66.200000   78.000000   74.000000    6.930000
# 75%     48.785000  102.237500   78.800000   88.000000   96.000000   11.055000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   34.450000
#
#                Date
# count  5.020000e+02
# mean   1.603090e+09
# std    7.177381e+01
# min    1.603090e+09
# 25%    1.603090e+09
# 50%    1.603090e+09
# 75%    1.603090e+09
# max    1.603090e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

humidity_indices = []

# if maximum humidity is greater than 100, add indices of cities with humidity greater than 100 to list
if city_df['Humidity'].max() > 100:
    # index through the cities
    for i in range(len(city_df.index)):
        # test for humidity level > 100 and append to list
        if city_df['Humidity'][i] > 100:
            humidity_indices.append(i)

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_data = city_df.drop(humidity_indices, inplace=False)

clean_city_data.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Gamba  -2.65   10.00     77.43        87          84        8.12
# 1  Nikolskoye  59.70   30.79     37.99        93          75        6.71
# 2     Samarai -10.62  150.67     80.62        86          94       12.08
# 3     Fayaoué -20.65  166.53     75.13        74          19        9.40
# 4   Ilulissat  69.22  -51.10     42.80        70         100       10.29
#
#   Country        Date
# 0      GA  1603090226
# 1      RU  1603090227
# 2      PG  1603090227
# 3      NC  1603090227
# 4      GL  1603090228

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat = clean_city_data[['Lat']]
temp = clean_city_data[['Max Temp']]

plt.scatter(lat, temp, edgecolors='black')
plt.grid(axis='both')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature (10/17/20)')

# export plot to output directory
plt.savefig('output_data/Fig1.png')

plt.show()

# The scatter plot shows what the different maximum temperatures are for the cities in the list, also showing how far
# each city is from the equator. It looks like the cities closest to the equator have the highest maximum temperatures.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat = clean_city_data[['Lat']]
hum = clean_city_data[['Humidity']]

plt.scatter(lat, hum, edgecolors='black')
plt.grid(axis='both')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (10/17/20)')

# export plot to output directory
plt.savefig('output_data/Fig2.png')

plt.show()

# This scatter plot shows the humidity of each city, compared to each city's distance from the equator. There seems to
# be a weaker relationship between the two variables, but cities to the north of the equator seem to have more humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat = clean_city_data[['Lat']]
cloud = clean_city_data[['Cloudiness']]

plt.scatter(lat, cloud, edgecolors='black')
plt.grid(axis='both')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (10/17/20)')

# export plot to output directory
plt.savefig('output_data/Fig3.png')

plt.show()

# This scatter plot shows a city's cloudiness percentage compared to its distance from the equator. There seems to
# be a weak relationship between the two, as cities all have differing cloudiness levels regardless of distance from
# the equator.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat = clean_city_data[['Lat']]
wind = clean_city_data[['Wind Speed']]

plt.scatter(lat, wind, edgecolors='black')
plt.grid(axis='both')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed (10/17/20)')

# export plot to output directory
plt.savefig('output_data/Fig4.png')

plt.show()

# From this scatter plot, we see that the very windiest cities are north of the equator, but there is not a
# strong relationship, as cities both close to and south of the equator seem to reach similar wind speeds.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_hem_df = clean_city_data.loc[clean_city_data['Lat'] > 0]

lat = north_hem_df['Lat']
temp = north_hem_df['Max Temp']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, temp)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, temp)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Northern Hemisphere - Latitude vs. Max Temp Linear Regression')
plt.show()
# Out:
# The r-value is: -0.8872797500794141

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_hem_df = clean_city_data.loc[clean_city_data['Lat'] < 0]

lat = south_hem_df['Lat']
temp = south_hem_df['Max Temp']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, temp)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, temp)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(200, 50), xycoords = 'figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Southern Hemisphere - Latitude vs. Max Temp Linear Regression')
plt.show()

# In the northern hemisphere, there is a strong negative correlation between latitude and maximum temperature, meaning
# the further north from the equator, the lower the temperatures. The same could be said for temperatures of cities to
# south of the equator. However, the graph shows a moderate positive correlation, as the distance decreases from the 
# equator, the maximum temperatures increase.
# Out:
# The r-value is: 0.6154789638103618

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat = north_hem_df['Lat']
hum = north_hem_df['Humidity']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, hum)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, hum)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(40,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Latitude vs. Humidity (%) Linear Regression')
plt.show()
# Out:
# The r-value is: 0.19846480395883317

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat = south_hem_df['Lat']
hum = south_hem_df['Humidity']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, hum)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, hum)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(200, 120), xycoords = 'figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Latitude vs. Humidity (%) Linear Regression')
plt.show()

# There is a very weak relationship between latitude and humidity percentage levels of cities both 
# north and south of the equator. The line plots are both very flat as there are not many data points that can
# fit into the line plot equation.
# Out:
# The r-value is: 0.13060897868758162

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat = north_hem_df['Lat']
cloud = north_hem_df['Cloudiness']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, cloud)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, cloud)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(40,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Latitude vs. Cloudiness (%) Linear Regression')
plt.show()
# Out:
# The r-value is: 0.14039723599524437

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat = south_hem_df['Lat']
cloud = south_hem_df['Cloudiness']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, cloud)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, cloud)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(200, 100), xycoords = 'figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Latitude vs. Cloudiness (%) Linear Regression')
plt.show()

# Like humidity, cloudiness percentage levels also have a very weak relationship with the latitude of the cities. 
# The r-values of the relationships show that there is close to no relationship between cloudiness and latitude of 
# a city.
# Out:
# The r-value is: 0.18603247902258357

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat = north_hem_df['Lat']
wind = north_hem_df['Wind Speed']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, wind)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, wind)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(150,180), xycoords='figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere - Latitude vs. Wind Speed (mph) Linear Regression')
plt.show()
# Out:
# The r-value is: 0.14359101784154282

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat = south_hem_df['Lat']
wind = south_hem_df['Wind Speed']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, wind)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, wind)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(200, 150), xycoords = 'figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere - Latitude vs. Wind Speed (mph) Linear Regression')
plt.show()

# Wind speeds and latitude of cities bear almost no relationship, explained by the weak r-values of the relationships
# between the two variables. The scatter plots and line graphs show that the line plot equations can explain very few
# data points at best, which means the correlation between the two variables is close to nil.
# Out:
# The r-value is: -0.2247016602042778
