# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Collecting citipy
#   Using cached citipy-0.0.5.tar.gz (557 kB)
# Collecting kdtree>=0.12
#   Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559701 sha256=fbe6c241ce1124c53864dd374fa54754bd60115b98823e1112ad586a884e4344
#   Stored in directory: /Users/m1nsun9/Library/Caches/pip/wheels/eb/07/14/1c448d9fabf3aceac66270933ecae15693974a1b7f91266841
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16

# %%
import pandas as pd
import json
import requests
import random as rand
import matplotlib.pyplot as plt
from api_keys import weather_api_key
from citipy import citipy
from scipy.stats import linregress

base_url = "http://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Generate Cities List

# %%
city_list = []

# create random geo-coordinates and use citipy to gather city names onto a list
for i in range(0, 550):
    city = citipy.nearest_city(rand.uniform(-90, 90), rand.uniform(-180, 180))
    
    # create while loop that re-rolls geo-coordinates for a city that isn't already in list
    while city.city_name in city_list:
        city = citipy.nearest_city(rand.uniform(-90, 90), rand.uniform(-180, 180))
    city_list.append(city.city_name)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_data = {
    'City': [],
    'Lat': [],
    'Lng': [],
    'Max Temp': [],
    'Humidity': [],
    'Cloudiness': [],
    'Wind Speed': [],
    'Country': [],
    'Date': []
}

print('Beginning Data Retrieval')
print('-----------------------------')


# iterate through city list and get API response and try to add information from each city into df dictionary
for i in range(len(city_list)):
    set_no = ((i + 1) // 50) + 1
    query_url = f"{base_url}q={city_list[i]}&appid={weather_api_key}&units=imperial"

    try:
        response = requests.get(query_url).json()
        city_data['City'].append(response['name'])
        city_data['Lat'].append(response['coord']['lat'])
        city_data['Lng'].append(response['coord']['lon'])
        city_data['Max Temp'].append(response['main']['temp_max'])
        city_data['Humidity'].append(response['main']['humidity'])
        city_data['Cloudiness'].append(response['clouds']['all'])
        city_data['Wind Speed'].append(response['wind']['speed'])
        city_data['Country'].append(response['sys']['country'])
        city_data['Date'].append(response['dt'])
        print(f"Processing Record {(i + 1) % 50} of Set {set_no} | {city_list[i]}")
    except KeyError:
        print('City not found. Skipping...')
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | saint-francois
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | swift current
# Processing Record 8 of Set 1 | terrace
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | nizhniy tsasuchey
# Processing Record 12 of Set 1 | ahipara
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | te anau
# Processing Record 15 of Set 1 | sioux lookout
# Processing Record 16 of Set 1 | praia da vitoria
# Processing Record 17 of Set 1 | arraial do cabo
# City not found. Skipping...
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | mwinilunga
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | tuatapere
# Processing Record 23 of Set 1 | stryn
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | nikki
# Processing Record 27 of Set 1 | sao joao da barra
# City not found. Skipping...
# Processing Record 29 of Set 1 | alofi
# Processing Record 30 of Set 1 | salgueiro
# Processing Record 31 of Set 1 | la romana
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | porto belo
# Processing Record 34 of Set 1 | zhigalovo
# Processing Record 35 of Set 1 | thunder bay
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | deputatskiy
# Processing Record 38 of Set 1 | camana
# City not found. Skipping...
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | yanam
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | norsup
# City not found. Skipping...
# Processing Record 46 of Set 1 | komsomolskiy
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | gayeri
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 0 of Set 2 | puerto ayora
# Processing Record 1 of Set 2 | auray
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | karratha
# Processing Record 4 of Set 2 | san cristobal
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | namibe
# Processing Record 7 of Set 2 | ovalle
# Processing Record 8 of Set 2 | morant bay
# Processing Record 9 of Set 2 | coihaique
# Processing Record 10 of Set 2 | turukhansk
# Processing Record 11 of Set 2 | chany
# Processing Record 12 of Set 2 | lavrentiya
# Processing Record 13 of Set 2 | nisia floresta
# Processing Record 14 of Set 2 | punta arenas
# City not found. Skipping...
# Processing Record 16 of Set 2 | ballina
# Processing Record 17 of Set 2 | wonthaggi
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | sangar
# Processing Record 20 of Set 2 | changji
# Processing Record 21 of Set 2 | tual
# Processing Record 22 of Set 2 | tabas
# Processing Record 23 of Set 2 | sao jose da coroa grande
# Processing Record 24 of Set 2 | voh
# Processing Record 25 of Set 2 | vuktyl
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | cabo san lucas
# Processing Record 28 of Set 2 | kem
# City not found. Skipping...
# Processing Record 30 of Set 2 | jimani
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | amapa
# Processing Record 34 of Set 2 | sola
# Processing Record 35 of Set 2 | hobart
# City not found. Skipping...
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | suez
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | geraldton
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | port macquarie
# Processing Record 44 of Set 2 | inhambane
# Processing Record 45 of Set 2 | istria
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | fastovetskaya
# Processing Record 48 of Set 2 | platanos
# Processing Record 49 of Set 2 | cabo rojo
# City not found. Skipping...
# Processing Record 1 of Set 3 | celestun
# Processing Record 2 of Set 3 | haines junction
# Processing Record 3 of Set 3 | torbay
# City not found. Skipping...
# Processing Record 5 of Set 3 | juneau
# Processing Record 6 of Set 3 | pangnirtung
# Processing Record 7 of Set 3 | lianzhou
# Processing Record 8 of Set 3 | pisco
# Processing Record 9 of Set 3 | bongandanga
# Processing Record 10 of Set 3 | jacobina
# Processing Record 11 of Set 3 | bilibino
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | kuzino
# Processing Record 14 of Set 3 | quelimane
# Processing Record 15 of Set 3 | conceicao do araguaia
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | monrovia
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | mount isa
# Processing Record 23 of Set 3 | loningen
# Processing Record 24 of Set 3 | calvinia
# Processing Record 25 of Set 3 | khatanga
# Processing Record 26 of Set 3 | broome
# City not found. Skipping...
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | akyab
# Processing Record 30 of Set 3 | kangaatsiaq
# Processing Record 31 of Set 3 | biak
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | ban nahin
# Processing Record 34 of Set 3 | qeshm
# Processing Record 35 of Set 3 | beihai
# City not found. Skipping...
# Processing Record 37 of Set 3 | hope
# Processing Record 38 of Set 3 | kholodnyy
# Processing Record 39 of Set 3 | phalodi
# Processing Record 40 of Set 3 | constitucion
# Processing Record 41 of Set 3 | mampong
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | upernavik
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | trairi
# Processing Record 47 of Set 3 | dudinka
# Processing Record 48 of Set 3 | mao
# City not found. Skipping...
# Processing Record 0 of Set 4 | narsaq
# Processing Record 1 of Set 4 | mumbwa
# City not found. Skipping...
# Processing Record 3 of Set 4 | gornopravdinsk
# Processing Record 4 of Set 4 | tirano
# Processing Record 5 of Set 4 | gizo
# Processing Record 6 of Set 4 | lucea
# Processing Record 7 of Set 4 | guanhaes
# Processing Record 8 of Set 4 | albany
# Processing Record 9 of Set 4 | debre zeyit
# Processing Record 10 of Set 4 | yarmouth
# Processing Record 11 of Set 4 | sawtell
# Processing Record 12 of Set 4 | tongling
# Processing Record 13 of Set 4 | chenghai
# Processing Record 14 of Set 4 | port blair
# Processing Record 15 of Set 4 | khani
# Processing Record 16 of Set 4 | hermon
# Processing Record 17 of Set 4 | lincoln
# Processing Record 18 of Set 4 | new norfolk
# City not found. Skipping...
# Processing Record 20 of Set 4 | tres arroyos
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | hambantota
# Processing Record 23 of Set 4 | sao felix do xingu
# Processing Record 24 of Set 4 | jumla
# Processing Record 25 of Set 4 | kahului
# Processing Record 26 of Set 4 | luderitz
# Processing Record 27 of Set 4 | warwick
# Processing Record 28 of Set 4 | mokhsogollokh
# Processing Record 29 of Set 4 | gat
# Processing Record 30 of Set 4 | georgetown
# City not found. Skipping...
# Processing Record 32 of Set 4 | avarua
# Processing Record 33 of Set 4 | konya
# Processing Record 34 of Set 4 | tiarei
# Processing Record 35 of Set 4 | avtury
# Processing Record 36 of Set 4 | sakharovo
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 4 | mayumba
# Processing Record 40 of Set 4 | cherskiy
# Processing Record 41 of Set 4 | srednekolymsk
# Processing Record 42 of Set 4 | kantunilkin
# Processing Record 43 of Set 4 | bidar
# Processing Record 44 of Set 4 | nome
# Processing Record 45 of Set 4 | coquimbo
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | hamilton
# City not found. Skipping...
# Processing Record 0 of Set 5 | namatanai
# City not found. Skipping...
# Processing Record 2 of Set 5 | verkhoyansk
# Processing Record 3 of Set 5 | moindou
# Processing Record 4 of Set 5 | ribeira grande
# Processing Record 5 of Set 5 | kununurra
# City not found. Skipping...
# Processing Record 7 of Set 5 | solnechnyy
# Processing Record 8 of Set 5 | general roca
# Processing Record 9 of Set 5 | nikolskoye
# Processing Record 10 of Set 5 | trat
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | port elizabeth
# City not found. Skipping...
# Processing Record 14 of Set 5 | kargat
# Processing Record 15 of Set 5 | vestmannaeyjar
# Processing Record 16 of Set 5 | valparaiso
# Processing Record 17 of Set 5 | tautira
# Processing Record 18 of Set 5 | bengkulu
# Processing Record 19 of Set 5 | taitung
# Processing Record 20 of Set 5 | auki
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 5 | orhangazi
# Processing Record 24 of Set 5 | la peca
# Processing Record 25 of Set 5 | araouane
# City not found. Skipping...
# Processing Record 27 of Set 5 | penzance
# Processing Record 28 of Set 5 | saint-denis
# Processing Record 29 of Set 5 | neyshabur
# Processing Record 30 of Set 5 | tocopilla
# Processing Record 31 of Set 5 | port lincoln
# Processing Record 32 of Set 5 | grand-lahou
# Processing Record 33 of Set 5 | nishihara
# Processing Record 34 of Set 5 | batagay-alyta
# Processing Record 35 of Set 5 | plettenberg bay
# Processing Record 36 of Set 5 | buala
# Processing Record 37 of Set 5 | yerofey pavlovich
# Processing Record 38 of Set 5 | skegness
# Processing Record 39 of Set 5 | bereda
# Processing Record 40 of Set 5 | chifeng
# Processing Record 41 of Set 5 | shar
# Processing Record 42 of Set 5 | san matias
# Processing Record 43 of Set 5 | aswan
# Processing Record 44 of Set 5 | isangel
# Processing Record 45 of Set 5 | itabira
# Processing Record 46 of Set 5 | opuwo
# Processing Record 47 of Set 5 | oistins
# Processing Record 48 of Set 5 | baoding
# Processing Record 49 of Set 5 | san quintin
# Processing Record 0 of Set 6 | kaitangata
# Processing Record 1 of Set 6 | huzhou
# Processing Record 2 of Set 6 | elliot lake
# Processing Record 3 of Set 6 | prince rupert
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | meulaboh
# Processing Record 6 of Set 6 | remuna
# Processing Record 7 of Set 6 | sabang
# Processing Record 8 of Set 6 | nenjiang
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | hami
# Processing Record 11 of Set 6 | husavik
# Processing Record 12 of Set 6 | klaksvik
# Processing Record 13 of Set 6 | andros
# Processing Record 14 of Set 6 | jumilla
# City not found. Skipping...
# Processing Record 16 of Set 6 | churapcha
# Processing Record 17 of Set 6 | daru
# Processing Record 18 of Set 6 | kingsville
# Processing Record 19 of Set 6 | la ronge
# Processing Record 20 of Set 6 | guerrero negro
# Processing Record 21 of Set 6 | beyneu
# Processing Record 22 of Set 6 | quechultenango
# Processing Record 23 of Set 6 | ciudad bolivar
# Processing Record 24 of Set 6 | omboue
# Processing Record 25 of Set 6 | abha
# Processing Record 26 of Set 6 | ibra
# Processing Record 27 of Set 6 | sar-e pul
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 6 | esperance
# City not found. Skipping...
# Processing Record 32 of Set 6 | bubaque
# Processing Record 33 of Set 6 | viedma
# Processing Record 34 of Set 6 | oyon
# Processing Record 35 of Set 6 | san patricio
# Processing Record 36 of Set 6 | hithadhoo
# Processing Record 37 of Set 6 | mortka
# Processing Record 38 of Set 6 | kloulklubed
# Processing Record 39 of Set 6 | ketchikan
# Processing Record 40 of Set 6 | vysokogornyy
# Processing Record 41 of Set 6 | torre del campo
# Processing Record 42 of Set 6 | muros
# Processing Record 43 of Set 6 | escarcega
# Processing Record 44 of Set 6 | clyde river
# Processing Record 45 of Set 6 | poum
# Processing Record 46 of Set 6 | luwuk
# Processing Record 47 of Set 6 | san francisco del mar
# Processing Record 48 of Set 6 | flin flon
# Processing Record 49 of Set 6 | dingle
# Processing Record 0 of Set 7 | rio gallegos
# Processing Record 1 of Set 7 | tabou
# Processing Record 2 of Set 7 | limoncito
# Processing Record 3 of Set 7 | makakilo city
# City not found. Skipping...
# Processing Record 5 of Set 7 | astoria
# Processing Record 6 of Set 7 | longavi
# Processing Record 7 of Set 7 | hearst
# Processing Record 8 of Set 7 | grand gaube
# Processing Record 9 of Set 7 | fortuna
# Processing Record 10 of Set 7 | olafsvik
# Processing Record 11 of Set 7 | kenai
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | dasoguz
# Processing Record 14 of Set 7 | esna
# Processing Record 15 of Set 7 | fairbanks
# Processing Record 16 of Set 7 | mazyr
# Processing Record 17 of Set 7 | ewa beach
# Processing Record 18 of Set 7 | nizhnekamsk
# Processing Record 19 of Set 7 | rodrigues alves
# Processing Record 20 of Set 7 | mount gambier
# Processing Record 21 of Set 7 | george town
# City not found. Skipping...
# Processing Record 23 of Set 7 | luchegorsk
# Processing Record 24 of Set 7 | catuday
# Processing Record 25 of Set 7 | lagoa
# City not found. Skipping...
# Processing Record 27 of Set 7 | omsukchan
# Processing Record 28 of Set 7 | brae
# Processing Record 29 of Set 7 | east london
# Processing Record 30 of Set 7 | dauphin
# City not found. Skipping...
# Processing Record 32 of Set 7 | vila velha
# Processing Record 33 of Set 7 | soyo
# Processing Record 34 of Set 7 | porto novo
# Processing Record 35 of Set 7 | ancud
# Processing Record 36 of Set 7 | hohhot
# Processing Record 37 of Set 7 | vardo
# Processing Record 38 of Set 7 | kananga
# Processing Record 39 of Set 7 | amuntai
# Processing Record 40 of Set 7 | damphu
# Processing Record 41 of Set 7 | bathsheba
# Processing Record 42 of Set 7 | victoria
# Processing Record 43 of Set 7 | huarmey
# Processing Record 44 of Set 7 | aykhal
# City not found. Skipping...
# Processing Record 46 of Set 7 | portland
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 7 | zhigansk
# Processing Record 0 of Set 8 | cidreira
# City not found. Skipping...
# Processing Record 2 of Set 8 | port moresby
# Processing Record 3 of Set 8 | punta alta
# Processing Record 4 of Set 8 | chake chake
# Processing Record 5 of Set 8 | mucurapo
# Processing Record 6 of Set 8 | half moon bay
# City not found. Skipping...
# Processing Record 8 of Set 8 | oussouye
# Processing Record 9 of Set 8 | inuvik
# City not found. Skipping...
# Processing Record 11 of Set 8 | axim
# Processing Record 12 of Set 8 | miraflores
# Processing Record 13 of Set 8 | port lavaca
# Processing Record 14 of Set 8 | road town
# Processing Record 15 of Set 8 | pochutla
# Processing Record 16 of Set 8 | catamarca
# Processing Record 17 of Set 8 | yulara
# Processing Record 18 of Set 8 | pingshan
# Processing Record 19 of Set 8 | snezhnogorsk
# Processing Record 20 of Set 8 | kavieng
# City not found. Skipping...
# Processing Record 22 of Set 8 | boende
# Processing Record 23 of Set 8 | tambovka
# Processing Record 24 of Set 8 | tilichiki
# Processing Record 25 of Set 8 | bousse
# Processing Record 26 of Set 8 | primorsko-akhtarsk
# Processing Record 27 of Set 8 | buchanan
# Processing Record 28 of Set 8 | cayenne
# Processing Record 29 of Set 8 | zyryanka
# Processing Record 30 of Set 8 | lahaina
# Processing Record 31 of Set 8 | talcahuano
# Processing Record 32 of Set 8 | ostrovnoy
# Processing Record 33 of Set 8 | saint-joseph
# Processing Record 34 of Set 8 | kaka
# City not found. Skipping...
# Processing Record 36 of Set 8 | saldanha
# City not found. Skipping...
# Processing Record 38 of Set 8 | rochegda
# Processing Record 39 of Set 8 | soe
# Processing Record 40 of Set 8 | sirjan
# Processing Record 41 of Set 8 | danilovka
# Processing Record 42 of Set 8 | broken hill
# Processing Record 43 of Set 8 | hoquiam
# Processing Record 44 of Set 8 | kota belud
# Processing Record 45 of Set 8 | lata
# Processing Record 46 of Set 8 | kavaratti
# Processing Record 47 of Set 8 | sambava
# Processing Record 48 of Set 8 | kjopsvik
# Processing Record 49 of Set 8 | ixtapa
# Processing Record 0 of Set 9 | lipari
# Processing Record 1 of Set 9 | kongolo
# Processing Record 2 of Set 9 | zhangye
# Processing Record 3 of Set 9 | thai binh
# Processing Record 4 of Set 9 | dunedin
# Processing Record 5 of Set 9 | bonthe
# Processing Record 6 of Set 9 | fort myers beach
# Processing Record 7 of Set 9 | richards bay
# Processing Record 8 of Set 9 | sinnamary
# Processing Record 9 of Set 9 | bambous virieux
# Processing Record 10 of Set 9 | boisoara
# Processing Record 11 of Set 9 | tolmezzo
# Processing Record 12 of Set 9 | princeton
# Processing Record 13 of Set 9 | udachnyy
# Processing Record 14 of Set 9 | rockport
# Processing Record 15 of Set 9 | apatity
# Processing Record 16 of Set 9 | raudeberg
# Processing Record 17 of Set 9 | gweta
# Processing Record 18 of Set 9 | mount darwin
# Processing Record 19 of Set 9 | huilong
# City not found. Skipping...
# Processing Record 21 of Set 9 | nemuro
# Processing Record 22 of Set 9 | ngaoundere
# Processing Record 23 of Set 9 | baruun-urt
# Processing Record 24 of Set 9 | bom jardim
# Processing Record 25 of Set 9 | gimli
# Processing Record 26 of Set 9 | adrar
# Processing Record 27 of Set 9 | the valley
# Processing Record 28 of Set 9 | airai
# Processing Record 29 of Set 9 | lobva
# Processing Record 30 of Set 9 | acari
# Processing Record 31 of Set 9 | magadan
# Processing Record 32 of Set 9 | cockburn town
# City not found. Skipping...
# Processing Record 34 of Set 9 | safford
# Processing Record 35 of Set 9 | hay river
# Processing Record 36 of Set 9 | buraydah
# Processing Record 37 of Set 9 | saint-pierre
# Processing Record 38 of Set 9 | mangrol
# Processing Record 39 of Set 9 | grindavik
# Processing Record 40 of Set 9 | nuuk
# Processing Record 41 of Set 9 | ornskoldsvik
# Processing Record 42 of Set 9 | beringovskiy
# Processing Record 43 of Set 9 | touros
# Processing Record 44 of Set 9 | itagi
# Processing Record 45 of Set 9 | merauke
# Processing Record 46 of Set 9 | mezen
# Processing Record 47 of Set 9 | katangli
# Processing Record 48 of Set 9 | san isidro
# Processing Record 49 of Set 9 | launceston
# Processing Record 0 of Set 10 | cairns
# Processing Record 1 of Set 10 | port hawkesbury
# Processing Record 2 of Set 10 | maragogi
# Processing Record 3 of Set 10 | mogzon
# Processing Record 4 of Set 10 | ostersund
# Processing Record 5 of Set 10 | saint george
# Processing Record 6 of Set 10 | diffa
# Processing Record 7 of Set 10 | orange
# Processing Record 8 of Set 10 | sindos
# Processing Record 9 of Set 10 | xinyu
# Processing Record 10 of Set 10 | liberal
# Processing Record 11 of Set 10 | tateyama
# Processing Record 12 of Set 10 | borovoy
# Processing Record 13 of Set 10 | lishui
# Processing Record 14 of Set 10 | lakes entrance
# Processing Record 15 of Set 10 | ozark
# City not found. Skipping...
# Processing Record 17 of Set 10 | buin
# Processing Record 18 of Set 10 | tongzi
# Processing Record 19 of Set 10 | garowe
# Processing Record 20 of Set 10 | jutai
# Processing Record 21 of Set 10 | naryan-mar
# Processing Record 22 of Set 10 | emerald
# Processing Record 23 of Set 10 | abu samrah
# Processing Record 24 of Set 10 | nola
# Processing Record 25 of Set 10 | altay
# Processing Record 26 of Set 10 | yumen
# Processing Record 27 of Set 10 | puerto narino
# Processing Record 28 of Set 10 | maniwaki
# Processing Record 29 of Set 10 | ukiah
# Processing Record 30 of Set 10 | hisar
# Processing Record 31 of Set 10 | razdolinsk
# Processing Record 32 of Set 10 | outjo
# City not found. Skipping...
# Processing Record 34 of Set 10 | kaeo
# Processing Record 35 of Set 10 | santa fe
# Processing Record 36 of Set 10 | villazon
# Processing Record 37 of Set 10 | usinsk
# Processing Record 38 of Set 10 | filingue
# Processing Record 39 of Set 10 | pilani
# Processing Record 40 of Set 10 | bonga
# Processing Record 41 of Set 10 | ulladulla
# Processing Record 42 of Set 10 | adre
# Processing Record 43 of Set 10 | montlucon
# Processing Record 44 of Set 10 | zainsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | grobenzell
# Processing Record 47 of Set 10 | flinders
# Processing Record 48 of Set 10 | teahupoo
# Processing Record 49 of Set 10 | vila do maio
# Processing Record 0 of Set 11 | swan hill
# Processing Record 1 of Set 11 | hobyo
# Processing Record 2 of Set 11 | chapais
# Processing Record 3 of Set 11 | nanzhang
# Processing Record 4 of Set 11 | muroto
# Processing Record 5 of Set 11 | nanortalik
# City not found. Skipping...
# Processing Record 7 of Set 11 | necochea
# Processing Record 8 of Set 11 | villa maria
# Processing Record 9 of Set 11 | bullhead city
# Processing Record 10 of Set 11 | batagay
# Processing Record 11 of Set 11 | barwadih
# Processing Record 12 of Set 11 | moree
# Processing Record 13 of Set 11 | san andres del rabanedo
# Processing Record 14 of Set 11 | diebougou
# Processing Record 15 of Set 11 | sahuaripa
# Processing Record 16 of Set 11 | lorengau
# Processing Record 17 of Set 11 | santarem
# Processing Record 18 of Set 11 | northam
# Processing Record 19 of Set 11 | tatarsk
# Processing Record 20 of Set 11 | maceio
# Processing Record 21 of Set 11 | kumluca
# Processing Record 22 of Set 11 | codrington
# City not found. Skipping...
# Processing Record 24 of Set 11 | mende
# Processing Record 25 of Set 11 | balsas
# Processing Record 26 of Set 11 | cap malheureux
# Processing Record 27 of Set 11 | kruisfontein
# Processing Record 28 of Set 11 | havre-saint-pierre
# Processing Record 29 of Set 11 | bourail
# Processing Record 30 of Set 11 | lavumisa
# Processing Record 31 of Set 11 | ilulissat
# Processing Record 32 of Set 11 | paamiut
# Processing Record 33 of Set 11 | olinda
# Processing Record 34 of Set 11 | marawi
# Processing Record 35 of Set 11 | juegang
# Processing Record 36 of Set 11 | souillac
# Processing Record 37 of Set 11 | karasjok
# Processing Record 38 of Set 11 | awjilah
# Processing Record 39 of Set 11 | muzhi
# Processing Record 40 of Set 11 | ustka
# Processing Record 41 of Set 11 | tibati
# Processing Record 42 of Set 11 | beloha
# Processing Record 43 of Set 11 | ulcinj
# Processing Record 44 of Set 11 | nouadhibou
# Processing Record 45 of Set 11 | danshui
# Processing Record 46 of Set 11 | kieta
# Processing Record 47 of Set 11 | chicama
# Processing Record 48 of Set 11 | vetluzhskiy
# Processing Record 49 of Set 11 | hirara
# Processing Record 0 of Set 12 | tyukalinsk

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create dataframe and export to csv
city_df = pd.DataFrame(city_data)
city_df.to_csv('output_data/cities.csv')

city_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Mataura -46.19  168.86     51.01        70         100        5.01
# 1           Bluff -46.60  168.33     51.01        70         100        5.01
# 2  Saint-François  46.42    3.91     35.60       100          90        1.12
# 3     Tuktoyaktuk  69.45 -133.04     13.59        92           0        5.55
# 4       Busselton -33.65  115.33     81.00        24           0        6.60
#
#   Country        Date
# 0      NZ  1603005537
# 1      NZ  1603005537
# 2      FR  1603005537
# 3      CA  1603005537
# 4      AU  1603005538

# %%
city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  503.000000  503.000000  503.000000  503.000000  503.000000  503.000000
# mean    19.223320   16.764513   60.611233   72.208748   53.644135    8.000815
# std     34.561361   93.219609   20.526452   21.841291   40.907224    5.435401
# min    -54.800000 -175.200000   10.400000    5.000000    0.000000    0.600000
# 25%     -9.735000  -65.650000   44.010000   62.500000   10.000000    4.000000
# 50%     22.290000   19.230000   64.990000   78.000000   63.000000    6.760000
# 75%     49.050000  102.500000   78.175000   88.000000   97.000000   10.815000
# max     78.220000  179.320000  100.400000  100.000000  100.000000   29.970000
#
#                Date
# count  5.030000e+02
# mean   1.603006e+09
# std    7.419743e+01
# min    1.603005e+09
# 25%    1.603006e+09
# 50%    1.603006e+09
# 75%    1.603006e+09
# max    1.603006e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

humidity_indices = []

# if maximum humidity is greater than 100, add indices of cities with humidity greater than 100 to list
if city_df['Humidity'].max() > 100:
    # index through the cities
    for i in range(len(city_df.index)):
        # test for humidity level > 100 and append to list
        if city_df['Humidity'][i] > 100:
            humidity_indices.append(i)

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_data = city_df.drop(humidity_indices, inplace=False)

clean_city_data.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Mataura -46.19  168.86     51.01        70         100        5.01
# 1           Bluff -46.60  168.33     51.01        70         100        5.01
# 2  Saint-François  46.42    3.91     35.60       100          90        1.12
# 3     Tuktoyaktuk  69.45 -133.04     13.59        92           0        5.55
# 4       Busselton -33.65  115.33     81.00        24           0        6.60
#
#   Country        Date
# 0      NZ  1603005537
# 1      NZ  1603005537
# 2      FR  1603005537
# 3      CA  1603005537
# 4      AU  1603005538

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat = clean_city_data[['Lat']]
temp = clean_city_data[['Max Temp']]

plt.scatter(lat, temp, edgecolors='black')
plt.grid(axis='both')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature (10/17/20)')

# export plot to output directory
plt.savefig('output_data/Fig1.png')

plt.show()

# The scatter plot shows what the different maximum temperatures are for the cities in the list, also showing how far
# each city is from the equator. It looks like the cities closest to the equator have the highest maximum temperatures.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat = clean_city_data[['Lat']]
hum = clean_city_data[['Humidity']]

plt.scatter(lat, hum, edgecolors='black')
plt.grid(axis='both')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (10/17/20)')

# export plot to output directory
plt.savefig('output_data/Fig2.png')

plt.show()

# This scatter plot shows the humidity of each city, compared to each city's distance from the equator. There seems to
# be a weaker relationship between the two variables, but cities to the north of the equator seem to have more humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat = clean_city_data[['Lat']]
cloud = clean_city_data[['Cloudiness']]

plt.scatter(lat, cloud, edgecolors='black')
plt.grid(axis='both')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (10/17/20)')

# export plot to output directory
plt.savefig('output_data/Fig3.png')

plt.show()

# This scatter plot shows a city's cloudiness percentage compared to its distance from the equator. There seems to
# be a weak relationship between the two, as cities all have differing cloudiness levels regardless of distance from
# the equator.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat = clean_city_data[['Lat']]
wind = clean_city_data[['Wind Speed']]

plt.scatter(lat, wind, edgecolors='black')
plt.grid(axis='both')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed (10/17/20)')

# export plot to output directory
plt.savefig('output_data/Fig4.png')

plt.show()

# From this scatter plot, we see that the very windiest cities are north of the equator, but there is not a
# strong relationship, as cities both close to and south of the equator seem to reach similar wind speeds.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_hem_df = clean_city_data.loc[clean_city_data['Lat'] > 0]

lat = north_hem_df['Lat']
temp = north_hem_df['Max Temp']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, temp)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, temp)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-value is: -0.8929991473523533

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_hem_df = clean_city_data.loc[clean_city_data['Lat'] < 0]

lat = south_hem_df['Lat']
temp = south_hem_df['Max Temp']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, temp)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, temp)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(200, 50), xycoords = 'figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

# In the northern hemisphere, there is a strong negative correlation between latitude and maximum temperature, meaning
# the further north from the equator, the lower the temperatures. The same could be said for temperatures of cities to
# south of the equator. However, the graph shows a moderate positive correlation, as the distance decreases from the 
# equator, the maximum temperatures increase.
# Out:
# The r-value is: 0.6632693018113668

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat = north_hem_df['Lat']
hum = north_hem_df['Humidity']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, hum)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, hum)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(40,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
# Out:
# The r-value is: 0.2175204235188991

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat = south_hem_df['Lat']
hum = south_hem_df['Humidity']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, hum)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, hum)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(200, 120), xycoords = 'figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()

# There is a very weak relationship between latitude and humidity percentage levels of cities both 
# north and south of the equator. The line plots are both very flat as there are not many data points that can
# fit into the line plot equation.
# Out:
# The r-value is: 0.050239199515714095

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat = north_hem_df['Lat']
cloud = north_hem_df['Cloudiness']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, cloud)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, cloud)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(40,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()
# Out:
# The r-value is: 0.24520987683284573

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat = south_hem_df['Lat']
cloud = south_hem_df['Cloudiness']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, cloud)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, cloud)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(200, 100), xycoords = 'figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# Like humidity, cloudiness percentage levels also have a very weak relationship with the latitude of the cities. 
# The r-values of the relationships show that there is close to no relationship between cloudiness and latitude of 
# a city.
# Out:
# The r-value is: 0.022042301092106278

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat = north_hem_df['Lat']
wind = north_hem_df['Wind Speed']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, wind)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, wind)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(150,180), xycoords='figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-value is: 0.16782499246783228

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat = south_hem_df['Lat']
wind = south_hem_df['Wind Speed']


(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, wind)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("The r-value is:", rvalue)

plt.scatter(lat, wind)
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(200, 150), xycoords = 'figure points', fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# Wind speeds and latitude of cities bear almost no relationship, explained by the weak r-values of the relationships
# between the two variables. The scatter plots and line graphs show that the line plot equations can explain very few
# data points at best, which means the correlation between the two variables is close to nil.
# Out:
# The r-value is: -0.12130232170608632
